# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import zipfile
import os
import glob
import math

# %%
data_path ="../data/mggg-states/"
states = pd.read_csv("../states.csv")
states
# Out:
#              state abbrev  districts                  file   dem_votes  \
# 0          Alabama     AL        7.0                   NaN         NaN
# 1           Alaska     AK        1.0                   NaN         NaN
# 2          Arizona     AZ        9.0          az_precincts      USH18D
# 3         Arkansas     AS        4.0                   NaN         NaN
# 4       California     CA       52.0                   NaN         NaN
# 5         Colorado     CO        8.0          CO_precincts      USH18D
# 6      Connecticut     CT        5.0          CT_precincts      USH18D
# 7         Delaware     DE        1.0                   NaN         NaN
# 8          Florida     FL       28.0                   NaN         NaN
# 9          Georgia     GA       14.0          GA_precincts     PRES16D
# 10          Hawaii     HI        2.0          HI_precincts      USH18D
# 11           Idaho     ID        2.0                   NaN         NaN
# 12        Illinois     IL       17.0                   NaN         NaN
# 13         Indiana     IN        9.0               Indiana     PRES16D
# 14            Iowa     IA        4.0           IA_counties     PRES16D
# 15          Kansas     KS        4.0                   NaN         NaN
# 16        Kentucky     KY        6.0                   NaN         NaN
# 17       Louisiana     LA        6.0               LA_1519     PRES16D
# 18           Maine     ME        2.0                 Maine      USH16D
# 19        Maryland     MD        8.0      MD_precincts_abs      USH18D
# 20   Massachusetts     MA        9.0    MA_precincts_12_16     PRES16D
# 21        Michigan     MI       13.0                    MI      SEN18D
# 22       Minnesota     MN        8.0               MN12_18      USH18D
# 23     Mississippi     MS        4.0                   NaN         NaN
# 24        Missouri     MO        8.0                   NaN         NaN
# 25         Montana     MT        2.0                   NaN         NaN
# 26        Nebraska     NE        3.0                    NE      USH18D
# 27          Nevada     NV        4.0                   NaN         NaN
# 28   New Hampshire     NH        2.0                    NH      USH20D
# 29      New Jersey     NJ       12.0                   NaN         NaN
# 30      New Mexico     NM        3.0  new_mexico_precincts      SEN18D
# 31        New York     NY       26.0                   NaN         NaN
# 32  North Carolina     NC       14.0                NC_VTD  EL16G_PR_D
# 33    North Dakota     ND        1.0                   NaN         NaN
# 34            Ohio     OH       15.0          OH_precincts      USH16D
# 35        Oklahoma     OK        5.0          OK_precincts      USH18D
# 36          Oregon     OR        6.0          OR_precincts      USH18D
# 37    Pennsylvania     PA       17.0          PA_2020_vtds      GOV14D
# 38    Rhode Island     RI        2.0          RI_precincts      SEN18D
# 39  South Carolina     CA        7.0                   NaN         NaN
# 40    South Dakota     SD        1.0                   NaN         NaN
# 41       Tennessee     TN        9.0                   NaN         NaN
# 42           Texas     TX       38.0                   NaN         NaN
# 43            Utah     UT        4.0          UT_precincts     PRES16D
# 44         Vermont     VT        1.0                   NaN         NaN
# 45        Virginia     VA       11.0          VA_precincts     G18DHOR
# 46      Washington     WA       10.0                   NaN         NaN
# 47   West Virginia     WV        2.0                   NaN         NaN
# 48       Wisconsin     WI        8.0              WI_vtd20      GOVD18
# 49         Wyoming     WY        1.0                   NaN         NaN
# 50             NaN    NaN        NaN                   NaN         NaN
#
#      rep_votes
# 0          NaN
# 1          NaN
# 2       USH18R
# 3          NaN
# 4          NaN
# 5       USH18R
# 6       USH18R
# 7          NaN
# 8          NaN
# 9      PRES16R
# 10      USH18R
# 11         NaN
# 12         NaN
# 13     PRES16R
# 14     PRES16R
# 15         NaN
# 16         NaN
# 17     PRES16R
# 18      USH16R
# 19      USH18R
# 20     PRES16R
# 21      SEN18R
# 22      USH18R
# 23         NaN
# 24         NaN
# 25         NaN
# 26      USH18R
# 27         NaN
# 28      USH20R
# 29         NaN
# 30      SEN18R
# 31         NaN
# 32  EL16G_PR_R
# 33         NaN
# 34      USH16R
# 35      USH18R
# 36      USH18R
# 37      GOV14R
# 38      SEN18R
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43     PRES16R
# 44         NaN
# 45     G18RHOR
# 46         NaN
# 47         NaN
# 48      GOVR18
# 49         NaN
# 50         NaN

# %%
for i,s in states.iterrows():
    if type(s["file"]) == float:
        if math.isnan(s["file"]):
            continue
    
    # with zipfile.ZipFile(os.path.join(data_path,f"{s['file']}.zip"), 'r') as zip_ref:
    #     zip_ref.extractall(os.path.join(data_path,s["abbrev"]))

    data = gpd.read_file()

# %%
# Out:
# float
