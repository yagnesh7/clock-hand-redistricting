# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import zipfile
import os
import glob
import math


import matplotlib.pyplot as plt
from scipy.stats import entropy
import shapely
import json
from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon
from tqdm import tqdm
import scorers
import redistricting

# %%
data_path = "../data/mggg-states/"
output_dir = "../output/"
states = pd.read_csv("../states_2010.csv")
DEGREE_LIMIT = 0
scoring = scorers.abs_diff_mean_fn
states
# Out:
#              state abbrev  districts                  file   dem_votes  \
# 0          Alabama     AL          7                   NaN         NaN
# 1           Alaska     AK          1                   NaN         NaN
# 2          Arizona     AZ          9          az_precincts      USH18D
# 3         Arkansas     AS          4                   NaN         NaN
# 4       California     CA         53                   NaN         NaN
# 5         Colorado     CO          7          CO_precincts      USH18D
# 6      Connecticut     CT          5          CT_precincts      USH18D
# 7         Delaware     DE          1                   NaN         NaN
# 8          Florida     FL         27                   NaN         NaN
# 9          Georgia     GA         14          GA_precincts     PRES16D
# 10          Hawaii     HI          2          HI_precincts      USH18D
# 11           Idaho     ID          2                   NaN         NaN
# 12        Illinois     IL         18                   NaN         NaN
# 13         Indiana     IN          9               Indiana     PRES16D
# 14            Iowa     IA          4           IA_counties     PRES16D
# 15          Kansas     KS          4                   NaN         NaN
# 16        Kentucky     KY          6                   NaN         NaN
# 17       Louisiana     LA          6               LA_1519     PRES16D
# 18           Maine     ME          2                 Maine      USH16D
# 19        Maryland     MD          8      MD_precincts_abs      USH18D
# 20   Massachusetts     MA          9    MA_precincts_12_16     PRES16D
# 21        Michigan     MI         14                    MI      SEN18D
# 22       Minnesota     MN          8               MN12_18      USH18D
# 23     Mississippi     MS          4                   NaN         NaN
# 24        Missouri     MO          8                   NaN         NaN
# 25         Montana     MT          1                   NaN         NaN
# 26        Nebraska     NE          3                    NE      USH18D
# 27          Nevada     NV          4                   NaN         NaN
# 28   New Hampshire     NH          2                    NH      USH20D
# 29      New Jersey     NJ         12                   NaN         NaN
# 30      New Mexico     NM          3  new_mexico_precincts      SEN18D
# 31        New York     NY         27                   NaN         NaN
# 32  North Carolina     NC         13                NC_VTD  EL16G_PR_D
# 33    North Dakota     ND          1                   NaN         NaN
# 34            Ohio     OH         16          OH_precincts      USH16D
# 35        Oklahoma     OK          5          OK_precincts      USH18D
# 36          Oregon     OR          5          OR_precincts      USH18D
# 37    Pennsylvania     PA         18          PA_2020_vtds  G18GOVDWOL
# 38    Rhode Island     RI          2          RI_precincts      SEN18D
# 39  South Carolina     CA          7                   NaN         NaN
# 40    South Dakota     SD          1                   NaN         NaN
# 41       Tennessee     TN          9                   NaN         NaN
# 42           Texas     TX         36                   NaN         NaN
# 43            Utah     UT          4          UT_precincts     PRES16D
# 44         Vermont     VT          1                   NaN         NaN
# 45        Virginia     VA         11          VA_precincts     G18DHOR
# 46      Washington     WA         10                   NaN         NaN
# 47   West Virginia     WV          3                   NaN         NaN
# 48       Wisconsin     WI          8              WI_vtd20      USH18D
# 49         Wyoming     WY          1                   NaN         NaN
#
#      rep_votes population
# 0          NaN        NaN
# 1          NaN        NaN
# 2       USH18R     TOTPOP
# 3          NaN        NaN
# 4          NaN        NaN
# 5       USH18R     TOTPOP
# 6       USH18R     TOTPOP
# 7          NaN        NaN
# 8          NaN        NaN
# 9      PRES16R     TOTPOP
# 10      USH18R     TOTPOP
# 11         NaN        NaN
# 12         NaN        NaN
# 13     PRES16R     TOTPOP
# 14     PRES16R     TOTPOP
# 15         NaN        NaN
# 16         NaN        NaN
# 17     PRES16R     TOTPOP
# 18      USH16R     TOTPOP
# 19      USH18R     TOTPOP
# 20     PRES16R     TOTPOP
# 21      SEN18R     TOTPOP
# 22      USH18R     TOTPOP
# 23         NaN        NaN
# 24         NaN        NaN
# 25         NaN        NaN
# 26      USH18R     TOTPOP
# 27         NaN        NaN
# 28      USH20R     TOTPOP
# 29         NaN        NaN
# 30      SEN18R     TOTPOP
# 31         NaN        NaN
# 32  EL16G_PR_R     TOTPOP
# 33         NaN        NaN
# 34      USH16R     TOTPOP
# 35      USH18R     TOTPOP
# 36      USH18R     TOTPOP
# 37  G18GOVRWAG   TOTPOP19
# 38      SEN18R     TOTPOP
# 39         NaN        NaN
# 40         NaN        NaN
# 41         NaN        NaN
# 42         NaN        NaN
# 43     PRES16R     TOTPOP
# 44         NaN     TOTPOP
# 45     G18RHOR     TOTPOP
# 46         NaN        NaN
# 47         NaN        NaN
# 48      USH18R   TOTPOP20
# 49         NaN        NaN
